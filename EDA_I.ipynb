# %% [markdown]
# <a href="https://colab.research.google.com/github/OMatheusWander/DataScienceUFSC/blob/main/EDA_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CIN/Data Science/alunos-2023-2/dataset/telecom_churn.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df['Churn'] = df ['Churn'].astype("int64")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   bool
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
df['Churn'].value_counts()[1]/df.shape[0]
# Out:
# 0.14491449144914492

# %%
df['Churn'].value_counts()
# Out:
# 483

# %% [markdown]
# ## Ordenação

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.sort_values(by='Total day charge', ascending=True).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1345    SD              98        415                 No              No
# 1397    VT             101        510                 No              No
# 2736    OK             127        510                 No             Yes
# 2753    OH             134        415                 No              No
# 1986    WI              70        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1345                      0                0.0                0
# 1397                      0                0.0                0
# 2736                     27                2.6              113
# 2753                      0                7.8               86
# 1986                      0                7.9              100
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by=['Churn', 'Total day charge'], ascending=[True, False]).head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 688     MN              13        510                 No             Yes
# 2259    NC             210        415                 No             Yes
# 534     LA              67        510                 No              No
# 575     SD             114        415                 No             Yes
# 2858    AL             141        510                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 688                      21              315.6              105
# 2259                     31              313.8               87
# 534                       0              310.4               97
# 575                      36              309.9               90
# 2858                     28              308.0              123
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# #### 1) Qual é a média de Total day charge para os clientes que vão embora?
# #### 2) Qual é a média de Total day charge para os clientes que ficam?
# #### 3) Qual dos dois acima é a maior média?

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df['Churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df[df['Churn'] == 0]['Total day charge'].mean()
# Out:
# 29.780421052631578

# %%
df[df['Churn'] == 1]

# %%
df[df['Churn'] == 1]['Total day charge'].mean()
# Out:
# 35.17592132505176

# %% [markdown]
# #### 4) Qual é o tamanho máximo das chamadas internacionais (Total intl minutes) para os usuários que ficam (churn==0) e para os usuário que vão embora(churn==1) que não tem Plano de Ligações internacionais(International plan).

# %%
df[(df['Churn'] == 0) & (df['International plan']=='No')]['Total intl minutes'].max()
# Out:
# 18.9

# %% [markdown]
# #### 5) Quais as médias, desvios padrões, maximos e mínimos dos "Total day minutes" e "Total night minutes" para os usuários que ficam e os que vão embora?

# %%
import numpy as np

# %%
df.groupby(['Churn'])[['Total day minutes','Total night minutes']].agg([np.mean, np.std, np.min, np.max, np.sum])
# Out:
#       Total day minutes                                  Total night minutes  \
#                    mean        std amin   amax       sum                mean
# Churn
# 0            175.175754  50.181655  0.0  315.6  499250.9          200.133193
# 1            206.914079  68.997792  0.0  350.8   99939.5          205.231677
#
#
#              std  amin   amax       sum
# Churn
# 0      51.105032  23.2  395.0  570379.6
# 1      47.132825  47.4  354.9   99126.9

# %% [markdown]
# #### 6) Qual tipo de Cliente(Churn) que tem as maiores somas e médias da soma de todas as ligações?
#
# > Bloco com avanço

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'NVM', 'Total day minutes', 'Total day calls',
#        'Total day charge', 'Total eve minutes', 'Total eve calls',
#        'Total eve charge', 'Total night minutes', 'Total night calls',
#        'Total night charge', 'Total intl minutes', 'Total intl calls',
#        'Total intl charge', 'CSC', 'Churn', 'Total Minutes Call'],
#       dtype='object')

# %%
df['Total Minutes Call'] = df['Total day minutes'] + df['Total intl minutes'] + df['Total eve minutes'] + df['Total night minutes']
df

# %%
df.groupby(['Churn'])[['Total Minutes Call']].agg([np.mean, np.sum])
# Out:
#       Total Minutes Call
#                     mean        sum
# Churn
# 0             584.511123  1665856.7
# 1             635.255901   306828.6

# %% [markdown]
# #### Algumas funções uteis:/

# %%
df.rename(columns={'Customer service calls': 'CSC', 'Number vmail messages':'NVM'}, inplace=True)

# %%
intpl = {'No':False, 'Yes': True}
newcolumn_mapped = df['International plan'].map(intpl)

df['International plan'] = newcolumn_mapped

# %%
df['International plan']
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331     True
# 3332    False
# Name: International plan, Length: 3333, dtype: bool

# %% [markdown]
# # Contexto
#
# ## Uma pessoa marca uma consulta médica, recebe todas as instruções e não comparece. Quem culpar?
# ## Quantidade de registros: 300k de consultas marcadas e 15 variáveis para cada consulta.

# %% [markdown]
# ## Dicionário de Dados
#
# * PatientId - Identificação de um paciente
# * AppointmentID - Identificação de cada consulta
# * Sexo = Masculino ou Feminino. O sexo feminino é a maior proporção, a mulher cuida muito mais da saúde em comparação com o homem.
# * DataMarcacaoConsulta = O dia da consulta atual, quando eles precisam visitar o médico.
# * DataAgendamento = O dia em que alguém ligou ou registrou o compromisso, isso é antes do compromisso, é claro.
# * Idade = Qual a idade do paciente.
# * Bairro = onde o compromisso ocorre. Bolsa = True or False.
# * Observação, este é um tópico amplo
# * Hipertensão = verdadeiro ou falso
# * Diabetes = verdadeiro ou falso
# * Alcoolismo = verdadeiro ou falso
# * Deficiente físico = verdadeiro ou falso
# * SMS = numero de mensagens recebidas por paciente
# * No-show = Verdadeiro ou Falso.

# %% [markdown]
# # Questões
# ##1- Qual o percentual de pacientes com e sem bolsa de estudos, Hipertensão, Diabetes, Alcoolismo, Handcap, SMS recebidos, comparecimento e ausência.
# ##2- Qual a porcentagem de homens que possuem e não possuem bolsa de estudos, Hipertensão, Diabetes, Alcoolismo, Handcap, SMS recebidos, comparecimento e ausência.
# ##3- Qual é o percentual de mulheres com e sem bolsa de estudos, Hipertensão, Diabetes, Alcoolismo, Handcap, SMS recebidas, comparecimento e ausência.
# ##4- Qual é o bairro em que o número mais elevado de pacientes recebe bolsa?
# ##5- Qual é o bairro que recebeu maior número de pacientes?
# ##6- Qual gênero tem mais bolsas?
# ##7- Qual é a idade do paciente que são Homens ou Mulheres?
# ##8- Qual a idade dos pacientes que são alcoolistas?
# ##9- Qual bairro recebe alta porcentagem de pacientes nos seguintes requisitos [Bolsa, Hipertensão, Diabetes, Alcoolismo, Handcap]?
# ##10- Qual o percentual de pacientes que receberam mensagem SMS e compareceram.

# %%
faltas = pd.read_csv('...faltas.csv')
